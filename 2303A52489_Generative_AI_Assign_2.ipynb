# %% [markdown]
# <a href="https://colab.research.google.com/github/SakethKandhukuri/Generative_AI_2303A52489/blob/main/2303A52489_Generative_AI_Assign_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.optimize import linprog

profit = [-6, -5]

constraints = [
    [1, 1],
    [3, 2]
]
bounds = [5, 12]


variable_bounds = [(0, None), (0, None)]

result = linprog(c=profit, A_ub=constraints, b_ub=bounds, bounds=variable_bounds, method="highs")

if result.success:
    print("Optimal Production:")
    print(f"Chocolate A: {result.x[0]:.2f} units")
    print(f"Chocolate B: {result.x[1]:.2f} units")
    print(f"Maximum Profit: ₹{-result.fun:.2f}")
else:
    print("No optimal solution found.")
# Out:
# Optimal Production:
# Chocolate A: 2.00 units
# Chocolate B: 3.00 units
# Maximum Profit: ₹27.00

# %% [markdown]
# ![WhatsApp Image 2025-01-10 at 14.12.27_1860ffbc.jpg](data:image/jpeg;base64,...)

# %%
from scipy.optimize import linprog

profit = [-50, -120]

constraints = [
    [1, 1],
    [7000, 2000],
    [10, 30]
]
bounds = [100, 700000, 1200]
variable_bounds = [(0, None), (0, None)]

result = linprog(c=profit, A_ub=constraints, b_ub=bounds, bounds=variable_bounds, method="highs")

print("Optimal Area Allocation:")
print(f"Wheat (x1): {result.x[0]:.2f} hectares")
print(f"Barley (x2): {result.x[1]:.2f} hectares")
print(f"Maximum Profit: ₹{(-result.fun):.2f}")
# Out:
# Optimal Area Allocation:
# Wheat (x1): 90.00 hectares
# Barley (x2): 10.00 hectares
# Maximum Profit: ₹5700.00

# %% [markdown]
# ![WhatsApp Image 2025-01-10 at 14.46.21_ea7be47d.jpg](data:image/jpeg;base64,...)
